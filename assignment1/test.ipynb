# %% [markdown]
# ## Q2_gradcheck

# %%
import random

# %%
random.getstate()
# Out:
# (3,
#  (2147483648,
#   2767223542,
#   996119610,
#   572125902,
#   2407636519,
#   3379931027,
#   2218337676,
#   2234557126,
#   4211517349,
#   2138062694,
#   3609303567,
#   1555879612,
#   734366874,
#   1098179248,
#   1814973851,
#   1977221192,
#   2405165450,
#   4213073286,
#   2228672865,
#   1860317949,
#   2685118532,
#   2434685952,
#   2697147433,
#   381724375,
#   3217703205,
#   263062803,
#   3519001997,
#   448797719,
#   2178108378,
#   488978895,
#   3176953855,
#   3421323176,
#   3553393051,
#   664084627,
#   2294590381,
#   453274782,
#   4097981982,
#   1617003794,
#   1101611735,
#   3850493398,
#   3695977412,
#   865354067,
#   1913853457,
#   2767035254,
#   3941155093,
#   853584182,
#   2692192370,
#   1001266627,
#   2449266781,
#   961117430,
#   2670164440,
#   1104975791,
#   1976535749,
#   2646294001,
#   2352928271,
#   2721947158,
#   2043042390,
#   2648644667,
#   4149902213,
#   3550347167,
#   597454965,
#   711424775,
#   803931691,
# ...

# %%
len(random.getstate())
# Out:
# 3

# %%
rndstate = random.getstate()

# %%
type(rndstate)
# Out:
# tuple

# %%
print(rndstate[0])
# Out:
# 3

# %%
print(rndstate[1])
# Out:
# (2147483648, 2767223542, 996119610, 572125902, 2407636519, 3379931027, 2218337676, 2234557126, 4211517349, 2138062694, 3609303567, 1555879612, 734366874, 1098179248, 1814973851, 1977221192, 2405165450, 4213073286, 2228672865, 1860317949, 2685118532, 2434685952, 2697147433, 381724375, 3217703205, 263062803, 3519001997, 448797719, 2178108378, 488978895, 3176953855, 3421323176, 3553393051, 664084627, 2294590381, 453274782, 4097981982, 1617003794, 1101611735, 3850493398, 3695977412, 865354067, 1913853457, 2767035254, 3941155093, 853584182, 2692192370, 1001266627, 2449266781, 961117430, 2670164440, 1104975791, 1976535749, 2646294001, 2352928271, 2721947158, 2043042390, 2648644667, 4149902213, 3550347167, 597454965, 711424775, 803931691, 3006532219, 1743662681, 1724220496, 2550805209, 1793178519, 1197545729, 1288479287, 1770753692, 1853600313, 124472278, 1403114689, 314473232, 1774893375, 379503240, 430222123, 2820580486, 4252469727, 148872090, 4114832667, 1475648772, 1795895663, 204903398
# ...

# %%
random.setstate(rndstate)

# %%
print(random.setstate(rndstate))
# Out:
# None

# %%
x = [1, 2, 3, 4]

# %%
import numpy as np

# %%
it = np.nditer(x)

# %%
print(it)
